# %% [markdown]
# ## importing libraries

# %%
import os  # Import the os module for file and directory operations
import pandas as pd  # Import the pandas library for data manipulation
import numpy as np  # Import the numpy library for numerical operations
import seaborn as sns  # Import the seaborn library for statistical data visualization
import matplotlib.pyplot as plt  # Import the pyplot module from matplotlib for creating static, animated, and interactive visualizations

# %% [markdown]
# ## getting a list of names of files

# %% [markdown]
# The code is presented within triple backticks (```) to indicate a code block.
# Comments are added above each logical section of the code to explain its purpose.
# The function definition is documented using docstrings, providing information about the function's purpose, arguments, and return value.

# %%
def process_directory(directory):
    """
    Process a directory and return a list of Excel files within it.

    Args:
    - directory (str): The path of the directory to process.

    Returns:
    - excel_files (list): A list of Excel file names found in the directory.
    """
    # Get a list of all files in the directory
    files = os.listdir(directory)

    # Filter the list to include only Excel files
    excel_files = [file for file in files if file.endswith('.xls') or file.endswith('.xlsx')]
    
    return excel_files

# %% [markdown]
# ## read excel files

# %% [markdown]
# The function read_data is defined to read data from an Excel file and return it as a DataFrame.
# Docstrings are used to document the purpose of the function, its arguments, and its return value.
# A comment is provided to explain the step of reading the Excel file and initializing the DataFrame.

# %%
def read_data(directory, file):
    """
    Read data from an Excel file and return a DataFrame.

    Args:
    - directory (str): The directory where the Excel file is located.
    - file (str): The name of the Excel file to read.

    Returns:
    - df (DataFrame): The DataFrame containing the data from the Excel file.
    """
    # Read the Excel file to initialize the DataFrame
    df = pd.read_excel(os.path.join(directory, file))
    
    return df

# %% [markdown]
# ## filtering the data of hospitals and their dates

# %% [markdown]
# The function extract_filtered_data takes a DataFrame df, a date string, and a mode integer as inputs and returns a DataFrame containing filtered data.
# Docstrings are used to document the purpose of the function, its arguments, and its return value.
# Comments are added to explain the conditional extraction of data based on the mode parameter and the filtering of data based on a specific condition.
# A list of dates corresponding to the filtered data is created and added as a new column to the DataFrame.

# %%
def extract_filtered_data(df, date, mode):
    """
    Extract filtered data from a DataFrame based on a condition.

    Args:
    - df (DataFrame): The DataFrame containing the data.
    - date (str): The date associated with the data.
    - mode (int): The mode of extraction. If 1, include the last column; otherwise, exclude it.

    Returns:
    - filtered_data (DataFrame): The DataFrame containing the filtered data.
    """
    # Extract data based on condition 
    if mode == 1:
        data = df.iloc[17:, 1:]  # Adjust column slicing here
    else:
        data = df.iloc[17:, 1:-1]

    # Filter data based on a specific condition (contains 'Bristol' in 'Unnamed: 3' column)
    filtered_data = data[data['Unnamed: 3'].str.contains('Bristol', case=False, na=False)]

    # Create a list of dates corresponding to the filtered data
    dates = [date] * filtered_data.shape[0]
    filtered_data['dates'] = dates

    return filtered_data

# %% [markdown]
# ## extracting and adding data headers from each data

# %% [markdown]
# The function process_df takes a DataFrame data as input and returns a processed DataFrame.
# Docstrings are used to document the purpose of the function, its arguments, and its return value.
# Comments are added to explain each step of the processing:
# Extracting header rows.
# Modifying header1 and combining it with header2.
# Removing header rows from the DataFrame.
# Setting the processed headers to the DataFrame columns.
# Finally, the index is reset, and the old index column is removed from the processed DataFrame.

# %%
def process_df(data):
    """
    Process the DataFrame by modifying headers and removing header rows.

    Args:
    - data (DataFrame): The DataFrame to be processed.

    Returns:
    - processed_data (DataFrame): The processed DataFrame.
    """
    # Extract header rows
    header1 = list(data.iloc[0, :])
    header2 = list(data.iloc[1, :])

    # Process header1
    temp_value = np.nan
    for i in range(len(header1)-1):
        if not pd.isna(header1[i]):
            temp_value = header1[i]
        else:
            header1[i] = temp_value

    # Combine header1 and header2
    for i in range(len(header2)):
        if not pd.isna(header1[i]):
            header2[i] = header1[i] + ' ' + header2[i]

    # Remove header rows from data
    data = data.iloc[2:, :]

    # Set the processed headers to the DataFrame columns
    data.columns = header2

    # Reset index and remove the old index column
    processed_data = data.reset_index().iloc[:, 1:]

    return processed_data

# %% [markdown]
# ## procecing and combinging all functions from pervious steps

# %% [markdown]
# The function process_excel_files takes a directory path directory and a processing mode mode as inputs and returns a processed DataFrame.
# Docstrings are used to document the purpose of the function, its arguments, and its return value.
# Comments are added to explain each step of the processing:
# Reading the first Excel file and extracting data.
# Iterating over subsequent Excel files, extracting data, and concatenating with the existing DataFrame.
# Extracting header information and adjusting column names based on the mode.
# Concatenating header and data, and processing the resulting DataFrame.

# %%
def process_excel_files(directory, mode):
    """
    Process Excel files from a directory based on a given mode.

    Args:
    - directory (str): The directory containing Excel files.
    - mode (int): The mode of processing.

    Returns:
    - data (DataFrame): The processed DataFrame.
    """
    # Read the first Excel file to initialize the DataFrame
    excel_files = process_directory(directory)
    temp_df = read_data(directory, excel_files[0])

    # Extract data based on condition for the first file
    date = excel_files[0].replace(".xls", "")
    temp_df = extract_filtered_data(temp_df, date, mode)
    
    # Adjust column names if mode is 3
    if mode == 3:
        temp_df.columns = [i for i in range(len(temp_df.columns))]

    # Iterate over each subsequent Excel file
    for file in excel_files[1:]:
        df = read_data(directory, file)
        
        date = file.replace(".xls", "")

        filtered_data = extract_filtered_data(df, date, mode)
        
        # Adjust column names if mode is 3
        if mode == 3:
            filtered_data.columns = [i for i in range(len(filtered_data.columns))]
        
        temp_df = pd.concat([temp_df, filtered_data], axis=0)

    # Extract header information
    if mode == 1:
        header = df.iloc[13:15, 1:]
        header['dates'] = [np.nan, 'dates']
        temp_df = temp_df.iloc[:, :-1]
    else:
        header = df.iloc[13:15, 1:-1]
        header['dates'] = [np.nan, 'dates']
        
    # Adjust column names if mode is 3
    if mode == 3:
        header.columns = [i for i in range(len(header.columns))]

    # Concatenate header and data, and process DataFrame
    concatenated_data = pd.concat([header, temp_df], axis=0)
    data = process_df(concatenated_data)
    
    date_column = list(data['dates'])

    month_dict = {
        'January': '01', 'February': '02', 'March': '03', 'April': '04',
        'May': '05', 'June': '06', 'July': '07', 'August': '08',
        'September': '09', 'October': '10', 'November': '11', 'December': '12'
    }
    new_dates = []
    
    for i in range(len(date_column)):
        
        parts = date_column[i].split('-')
        
        new_date = parts[1] + '/' + month_dict[parts[0]]
        
        new_dates.append(new_date)

    data.drop('dates', axis=1, inplace=True)  # Drop the original column
    
    data['dates'] = pd.to_datetime(new_dates, format='%Y/%m/%d')

    return data

# %% [markdown]
# ## merging the all three files and doing data cleaning
#
#
# Data for different time periods (2015-2017, 2017-2018, and 2018-2024) is processed separately.
# Columns deemed unnecessary are dropped from the datasets data_2018_2024 and data_2017_2018.
# The datasets data_2015_2017 and data_2015_2017 are concatenated with additional columns added to data_2015_2017.
# Column names of data_2015_2017 are adjusted to match those of data_2017_2024.
# The final dataset data_2015_2024 is formed by concatenating data_2017_2024 and data_2015_2017.
# The resulting dataset is saved as a CSV file.

# %%
# For processing data from 2015 to 2017
file_path = "2015-2017"
data_2015_2017 = process_excel_files(file_path, 1)

# For processing data from 2018 to 2024
file_path = "2018-2024"
data_2018_2024 = process_excel_files(file_path, 3)

# For processing data from 2017 to 2018
file_path = "2017-2018"
data_2017_2018 = process_excel_files(file_path, 2)

# Dropping columns from data_2018_2024
columns_to_drop = ['Percentage of attendances within 4 hours Percentage in 4 hours or less (all)',
                   'Percentage of attendances within 4 hours Percentage in 4 hours or less (type 1)',
                   'Percentage of attendances within 4 hours Percentage in 4 hours or less (type 2)',
                   'Percentage of attendances within 4 hours Percentage in 4 hours or less (type 3)']
data_2018_2024 = data_2018_2024.drop(columns=columns_to_drop)

# Dropping columns from data_2017_2018
columns_to_drop = ['Percentage of attendances within 4 hours Percentage in 4 hours or less (type 1)',
                   'Percentage of attendances within 4 hours Percentage in 4 hours or less (all)']
data_2017_2018 = data_2017_2018.drop(columns=columns_to_drop)

# Concatenating data_2018_2024 and data_2017_2018
data_2017_2024 = pd.concat([data_2018_2024, data_2017_2018])

# Creating new columns for data_2015_2017
New_Column1 = data_2015_2017['A&E attendances Type 1 Departments - Major A&E'].astype(float) - data_2015_2017['A&E attendances > 4 hours from arrival to admission, transfer or discharge Type 1 Departments - Major A&E'].astype(float)
New_Column2 = data_2015_2017['A&E attendances Type 2 Departments - Single Specialty'].astype(float) - data_2015_2017['A&E attendances > 4 hours from arrival to admission, transfer or discharge Type 2 Departments - Single Specialty'].astype(float)
New_Column3 = data_2015_2017['A&E attendances Type 3 Departments - Other A&E/Minor Injury Unit'].astype(float) - data_2015_2017['A&E attendances > 4 hours from arrival to admission, transfer or discharge Type 3 Departments - Other A&E/Minor Injury Unit'].astype(float)
New_Column4 = data_2015_2017['A&E attendances Total attendances'].astype(float) - data_2015_2017['A&E attendances > 4 hours from arrival to admission, transfer or discharge Total Attendances > 4 hours'].astype(float)

# Inserting new columns to data_2015_2017
data_2015_2017.insert(loc=7, column='A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 1 Departments - Major A&E', value=New_Column1)
data_2015_2017.insert(loc=8, column='A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 2 Departments - Single Specialty', value=New_Column2)
data_2015_2017.insert(loc=9, column='A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 3 Departments - Other A&E/Minor Injury Unit', value=New_Column3)
data_2015_2017.insert(loc=10, column='A&E attendances less than 4 hours from arrival to admission, transfer or discharge Total Attendances < 4 hours', value=New_Column4)

# Dropping columns from data_2015_2017
columns_to_drop = ['A&E attendances > 4 hours from arrival to admission, transfer or discharge Percentage in 4 hours or less (type 1)',
                   'A&E attendances > 4 hours from arrival to admission, transfer or discharge Percentage in 4 hours or less (all)']
data_2015_2017 = data_2015_2017.drop(columns=columns_to_drop)

# Renaming columns of data_2015_2017 to match data_2017_2024
data_2015_2017.columns = data_2017_2024.columns

# Concatenating data_2017_2024 and data_2015_2017
data_2015_2024 = pd.concat([data_2017_2024, data_2015_2017])

# Saving the concatenated data to a CSV file
data_2015_2024.to_csv('health data bristol.csv', index=False)
# Out:
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates
# C:\Users\Aidyn\AppData\Local\Temp\ipykernel_22592\1175261537.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['dates'] = dates

# %%
data_2015_2024
# Out:
#    Code                                 Region  \
# 0   NLW                NHS England South West
# 1   RVJ                NHS England South West
# 2   RA7                NHS England South West
# 3   NLW                NHS England South West
# 4   RVJ                NHS England South West
# ..  ...                                    ...
# 61  RVJ  South Of England Commissioning Region
# 62  RA7  South Of England Commissioning Region
# 63  NLW  South Of England Commissioning Region
# 64  RVJ  South Of England Commissioning Region
# 65  RA7  South Of England Commissioning Region
#
#                                                  Name  \
# 0                            Bristol Community Health
# 1                             North Bristol NHS Trust
# 2   University Hospitals Bristol NHS Foundation Trust
# 3                            Bristol Community Health
# 4                             North Bristol NHS Trust
# ..                                                ...
# 61                            North Bristol NHS Trust
# 62  University Hospitals Bristol NHS Foundation Trust
# 63                           Bristol Community Health
# 64                            North Bristol NHS Trust
# 65  University Hospitals Bristol NHS Foundation Trust
#
#    A&E attendances Type 1 Departments - Major A&E  \
# 0                                               0
# 1                                            7429
# 2                                            9569
# 3                                               0
# 4                                            7934
# ..                                            ...
# 61                                           7049
# 62                                           8563
# 63                                              0
# 64                                           7329
# 65                                           8753
#
#    A&E attendances Type 2 Departments - Single Specialty  \
# 0                                                   0
# 1                                                   0
# 2                                                2036
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                               1768
# 63                                                  0
# 64                                                  0
# 65                                               1889
#
#    A&E attendances Type 3 Departments - Other A&E/Minor Injury Unit  \
# 0                                                4560
# 1                                                   0
# 2                                                   0
# 3                                                4839
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                               5073
# 64                                                  0
# 65                                                  0
#
#    A&E attendances Total attendances  \
# 0                               4560
# 1                               7429
# 2                              11605
# 3                               4839
# 4                               7934
# ..                               ...
# 61                              7049
# 62                             10331
# 63                              5073
# 64                              7329
# 65                             10642
#
#    A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 1 Departments - Major A&E  \
# 0                                                   0
# 1                                                6168
# 2                                                7821
# 3                                                   0
# 4                                                5532
# ..                                                ...
# 61                                             6241.0
# 62                                             7708.0
# 63                                                0.0
# 64                                             6135.0
# 65                                             7419.0
#
#    A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 2 Departments - Single Specialty  \
# 0                                                   0
# 1                                                   0
# 2                                                1922
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 61                                                0.0
# 62                                             1764.0
# 63                                                0.0
# 64                                                0.0
# 65                                             1875.0
#
#    A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 3 Departments - Other A&E/Minor Injury Unit  \
# 0                                                4555
# 1                                                   0
# 2                                                   0
# 3                                                4832
# 4                                                   0
# ..                                                ...
# 61                                                0.0
# 62                                                0.0
# 63                                             4994.0
# 64                                                0.0
# 65                                                0.0
#
#     ...  \
# 0   ...
# 1   ...
# 2   ...
# 3   ...
# 4   ...
# ..  ...
# 61  ...
# 62  ...
# 63  ...
# 64  ...
# 65  ...
#
#    A&E attendances greater than 4 hours from arrival to admission, transfer or discharge Total Attendances > 4 hours  \
# 0                                                   5
# 1                                                1261
# 2                                                1862
# 3                                                   7
# 4                                                2402
# ..                                                ...
# 61                                                808
# 62                                                859
# 63                                                 79
# 64                                               1194
# 65                                               1348
#
#    Emergency Admissions Emergency Admissions via Type 1 A&E  \
# 0                                                   0
# 1                                                2536
# 2                                                2985
# 3                                                   0
# 4                                                3183
# ..                                                ...
# 61                                               2305
# 62                                               2725
# 63                                                  0
# 64                                               2598
# 65                                               2712
#
#    Emergency Admissions Emergency Admissions via Type 2 A&E  \
# 0                                                   0
# 1                                                   0
# 2                                                   9
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                 13
# 63                                                  0
# 64                                                  0
# 65                                                 15
#
#    Emergency Admissions Emergency Admissions via Type 3 and 4 A&E  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                                                  0
# 65                                                  0
#
#    Emergency Admissions Total Emergency Admissions via A&E  \
# 0                                                   0
# 1                                                2536
# 2                                                2994
# 3                                                   0
# 4                                                3183
# ..                                                ...
# 61                                               2305
# 62                                               2738
# 63                                                  0
# 64                                               2598
# 65                                               2727
#
#    Emergency Admissions Other Emergency admissions (i.e not via A&E)  \
# 0                                                   0
# 1                                                1659
# 2                                                 838
# 3                                                   0
# 4                                                1772
# ..                                                ...
# 61                                               1175
# 62                                                650
# 63                                                  0
# 64                                               1247
# 65                                                672
#
#    Emergency Admissions Total Emergency Admissions  \
# 0                                                0
# 1                                             4195
# 2                                             3832
# 3                                                0
# 4                                             4955
# ..                                             ...
# 61                                            3480
# 62                                            3388
# 63                                               0
# 64                                            3845
# 65                                            3399
#
#    Emergency Admissions Number of patients spending >4 hours from decision to admit to admission  \
# 0                                                   0
# 1                                                 373
# 2                                                 396
# 3                                                   0
# 4                                                 666
# ..                                                ...
# 61                                                307
# 62                                                293
# 63                                                  0
# 64                                                393
# 65                                                347
#
#    Emergency Admissions Number of patients spending >12 hours from decision to admit to admission  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 61                                                  0
# 62                                                  0
# 63                                                  0
# 64                                                  3
# 65                                                  1
#
#         dates
# 0  2018-04-01
# 1  2018-04-01
# 2  2018-04-01
# 3  2019-04-01
# 4  2019-04-01
# ..        ...
# 61 2015-09-01
# 62 2015-09-01
# 63 2016-09-01
# 64 2016-09-01
# 65 2016-09-01
#
# [266 rows x 24 columns]

# %% [markdown]
# ## data visulisation and setting date
#
# The 'dates' column is converted to datetime format using pd.to_datetime.
# 'year' column is extracted from 'dates' using dt.year.
# A loop iterates over each column (excluding the first 3 and last 2) to create line plots using Seaborn's lineplot function.
# Inside the loop:
# A new figure is created for each plot with adjusted width and height using plt.figure.
# Line plot is created using Seaborn's lineplot function, specifying 'dates' as the x-axis, the current column as the y-axis, and 'Name' as the hue.
# x-axis labels are rotated for better visibility using plt.xticks(rotation=90).
# A title is set for each plot using ax.set_title.
# The plot is displayed using plt.show().
# Finally, the correlation matrix is calculated using .corr() on the selected columns

# %%
data=data_2015_2024

# Convert 'dates' column to datetime format
data['dates'] = pd.to_datetime(data['dates'], format='%B-%Y')

# Extract 'year' from 'dates'
data['year'] = data['dates'].dt.year

# Iterate over each column (excluding first 3 and last 2) to create line plots
for column in data.columns[3:-2]:
    # Create a new figure for each plot with adjusted width and height
    plt.figure(figsize=(15, 10))

    # Create line plot using Seaborn's lineplot function
    ax = sns.lineplot(data=data, x='dates', y=column, hue='Name')

    # Rotate x-axis labels for better visibility
    plt.xticks(rotation=90)

    # Set title for the plot
    ax.set_title(column + ' over time')

    # Show the plot
    plt.show()

# Convert selected columns to numeric data type, replacing non-convertible values with NaN
data = data.iloc[:, 3:-2].apply(pd.to_numeric, errors='coerce')


# Calculate correlation matrix for the converted numeric columns
correlation_matrix = data.corr()

correlation_matrix
# Out:
#                                                     A&E attendances Type 1 Departments - Major A&E  \
# A&E attendances Type 1 Departments - Major A&E                                            1.000000
# A&E attendances Type 2 Departments - Single Spe...                                        0.688076
# A&E attendances Type 3 Departments - Other A&E/...                                       -0.866949
# A&E attendances Total attendances                                                         0.917808
# A&E attendances less than 4 hours from arrival ...                                        0.950618
# A&E attendances less than 4 hours from arrival ...                                        0.684640
# A&E attendances less than 4 hours from arrival ...                                       -0.867069
# A&E attendances less than 4 hours from arrival ...                                        0.786301
# A&E attendances greater than 4 hours from arriv...                                        0.837590
# A&E attendances greater than 4 hours from arriv...                                        0.632007
# A&E attendances greater than 4 hours from arriv...                                       -0.553663
# A&E attendances greater than 4 hours from arriv...                                        0.837352
# Emergency Admissions Emergency Admissions via T...                                        0.968622
# Emergency Admissions Emergency Admissions via T...                                        0.574138
# Emergency Admissions Emergency Admissions via T...                                             NaN
# Emergency Admissions Total Emergency Admissions...                                        0.969032
# Emergency Admissions Other Emergency admissions...                                        0.592397
# Emergency Admissions Total Emergency Admissions                                           0.912372
# Emergency Admissions Number of patients spendin...                                        0.782585
# Emergency Admissions Number of patients spendin...                                        0.506022
#
#                                                     A&E attendances Type 2 Departments - Single Specialty  \
# A&E attendances Type 1 Departments - Major A&E                                               0.688076
# A&E attendances Type 2 Departments - Single Spe...                                           1.000000
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.416600
# A&E attendances Total attendances                                                            0.864411
# A&E attendances less than 4 hours from arrival ...                                           0.691032
# A&E attendances less than 4 hours from arrival ...                                           0.999759
# A&E attendances less than 4 hours from arrival ...                                          -0.416658
# A&E attendances less than 4 hours from arrival ...                                           0.941963
# A&E attendances greater than 4 hours from arriv...                                           0.511314
# A&E attendances greater than 4 hours from arriv...                                           0.784035
# A&E attendances greater than 4 hours from arriv...                                          -0.266055
# A&E attendances greater than 4 hours from arriv...                                           0.519054
# Emergency Admissions Emergency Admissions via T...                                           0.582104
# Emergency Admissions Emergency Admissions via T...                                           0.911511
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.584597
# Emergency Admissions Other Emergency admissions...                                          -0.088404
# Emergency Admissions Total Emergency Admissions                                              0.402022
# Emergency Admissions Number of patients spendin...                                           0.450109
# Emergency Admissions Number of patients spendin...                                           0.335394
#
#                                                     A&E attendances Type 3 Departments - Other A&E/Minor Injury Unit  \
# A&E attendances Type 1 Departments - Major A&E                                              -0.866949
# A&E attendances Type 2 Departments - Single Spe...                                          -0.416600
# A&E attendances Type 3 Departments - Other A&E/...                                           1.000000
# A&E attendances Total attendances                                                           -0.615067
# A&E attendances less than 4 hours from arrival ...                                          -0.909271
# A&E attendances less than 4 hours from arrival ...                                          -0.417018
# A&E attendances less than 4 hours from arrival ...                                           0.999983
# A&E attendances less than 4 hours from arrival ...                                          -0.519207
# A&E attendances greater than 4 hours from arriv...                                          -0.576296
# A&E attendances greater than 4 hours from arriv...                                          -0.311971
# A&E attendances greater than 4 hours from arriv...                                           0.658657
# A&E attendances greater than 4 hours from arriv...                                          -0.571498
# Emergency Admissions Emergency Admissions via T...                                          -0.914913
# Emergency Admissions Emergency Admissions via T...                                          -0.383448
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                          -0.914671
# Emergency Admissions Other Emergency admissions...                                          -0.793519
# Emergency Admissions Total Emergency Admissions                                             -0.939201
# Emergency Admissions Number of patients spendin...                                          -0.554527
# Emergency Admissions Number of patients spendin...                                          -0.235925
#
#                                                     A&E attendances Total attendances  \
# A&E attendances Type 1 Departments - Major A&E                               0.917808
# A&E attendances Type 2 Departments - Single Spe...                           0.864411
# A&E attendances Type 3 Departments - Other A&E/...                          -0.615067
# A&E attendances Total attendances                                            1.000000
# A&E attendances less than 4 hours from arrival ...                           0.835976
# A&E attendances less than 4 hours from arrival ...                           0.859968
# A&E attendances less than 4 hours from arrival ...                          -0.615237
# A&E attendances less than 4 hours from arrival ...                           0.912772
# A&E attendances greater than 4 hours from arriv...                           0.833009
# A&E attendances greater than 4 hours from arriv...                           0.797545
# A&E attendances greater than 4 hours from arriv...                          -0.381979
# A&E attendances greater than 4 hours from arriv...                           0.837309
# Emergency Admissions Emergency Admissions via T...                           0.826640
# Emergency Admissions Emergency Admissions via T...                           0.721762
# Emergency Admissions Emergency Admissions via T...                                NaN
# Emergency Admissions Total Emergency Admissions...                           0.827910
# Emergency Admissions Other Emergency admissions...                           0.264615
# Emergency Admissions Total Emergency Admissions                              0.699106
# Emergency Admissions Number of patients spendin...                           0.762499
# Emergency Admissions Number of patients spendin...                           0.570752
#
#                                                     A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 1 Departments - Major A&E  \
# A&E attendances Type 1 Departments - Major A&E                                               0.950618
# A&E attendances Type 2 Departments - Single Spe...                                           0.691032
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.909271
# A&E attendances Total attendances                                                            0.835976
# A&E attendances less than 4 hours from arrival ...                                           1.000000
# A&E attendances less than 4 hours from arrival ...                                           0.690685
# A&E attendances less than 4 hours from arrival ...                                          -0.909397
# A&E attendances less than 4 hours from arrival ...                                           0.818009
# A&E attendances greater than 4 hours from arriv...                                           0.626677
# A&E attendances greater than 4 hours from arriv...                                           0.546914
# A&E attendances greater than 4 hours from arriv...                                          -0.580691
# A&E attendances greater than 4 hours from arriv...                                           0.626417
# Emergency Admissions Emergency Admissions via T...                                           0.943526
# Emergency Admissions Emergency Admissions via T...                                           0.612042
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.944135
# Emergency Admissions Other Emergency admissions...                                           0.586030
# Emergency Admissions Total Emergency Admissions                                              0.891877
# Emergency Admissions Number of patients spendin...                                           0.573948
# Emergency Admissions Number of patients spendin...                                           0.273178
#
#                                                     A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 2 Departments - Single Specialty  \
# A&E attendances Type 1 Departments - Major A&E                                               0.684640
# A&E attendances Type 2 Departments - Single Spe...                                           0.999759
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.417018
# A&E attendances Total attendances                                                            0.859968
# A&E attendances less than 4 hours from arrival ...                                           0.690685
# A&E attendances less than 4 hours from arrival ...                                           1.000000
# A&E attendances less than 4 hours from arrival ...                                          -0.417076
# A&E attendances less than 4 hours from arrival ...                                           0.941257
# A&E attendances greater than 4 hours from arriv...                                           0.503297
# A&E attendances greater than 4 hours from arriv...                                           0.770228
# A&E attendances greater than 4 hours from arriv...                                          -0.266322
# A&E attendances greater than 4 hours from arriv...                                           0.510850
# Emergency Admissions Emergency Admissions via T...                                           0.579564
# Emergency Admissions Emergency Admissions via T...                                           0.913351
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.582070
# Emergency Admissions Other Emergency admissions...                                          -0.091339
# Emergency Admissions Total Emergency Admissions                                              0.399179
# Emergency Admissions Number of patients spendin...                                           0.443190
# Emergency Admissions Number of patients spendin...                                           0.327112
#
#                                                     A&E attendances less than 4 hours from arrival to admission, transfer or discharge Type 3 Departments - Other A&E/Minor Injury Unit  \
# A&E attendances Type 1 Departments - Major A&E                                              -0.867069
# A&E attendances Type 2 Departments - Single Spe...                                          -0.416658
# A&E attendances Type 3 Departments - Other A&E/...                                           0.999983
# A&E attendances Total attendances                                                           -0.615237
# A&E attendances less than 4 hours from arrival ...                                          -0.909397
# A&E attendances less than 4 hours from arrival ...                                          -0.417076
# A&E attendances less than 4 hours from arrival ...                                           1.000000
# A&E attendances less than 4 hours from arrival ...                                          -0.519380
# A&E attendances greater than 4 hours from arriv...                                          -0.576376
# A&E attendances greater than 4 hours from arriv...                                          -0.312014
# A&E attendances greater than 4 hours from arriv...                                           0.654242
# A&E attendances greater than 4 hours from arriv...                                          -0.571616
# Emergency Admissions Emergency Admissions via T...                                          -0.915040
# Emergency Admissions Emergency Admissions via T...                                          -0.383501
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                          -0.914798
# Emergency Admissions Other Emergency admissions...                                          -0.793629
# Emergency Admissions Total Emergency Admissions                                             -0.939331
# Emergency Admissions Number of patients spendin...                                          -0.554604
# Emergency Admissions Number of patients spendin...                                          -0.235958
#
#                                                     A&E attendances less than 4 hours from arrival to admission, transfer or discharge Total Attendances < 4 hours  \
# A&E attendances Type 1 Departments - Major A&E                                               0.786301
# A&E attendances Type 2 Departments - Single Spe...                                           0.941963
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.519207
# A&E attendances Total attendances                                                            0.912772
# A&E attendances less than 4 hours from arrival ...                                           0.818009
# A&E attendances less than 4 hours from arrival ...                                           0.941257
# A&E attendances less than 4 hours from arrival ...                                          -0.519380
# A&E attendances less than 4 hours from arrival ...                                           1.000000
# A&E attendances greater than 4 hours from arriv...                                           0.534440
# A&E attendances greater than 4 hours from arriv...                                           0.752088
# A&E attendances greater than 4 hours from arriv...                                          -0.318661
# A&E attendances greater than 4 hours from arriv...                                           0.540951
# Emergency Admissions Emergency Admissions via T...                                           0.696841
# Emergency Admissions Emergency Admissions via T...                                           0.833066
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.698802
# Emergency Admissions Other Emergency admissions...                                           0.072371
# Emergency Admissions Total Emergency Admissions                                              0.539827
# Emergency Admissions Number of patients spendin...                                           0.460511
# Emergency Admissions Number of patients spendin...                                           0.287163
#
#                                                     A&E attendances greater than 4 hours from arrival to admission, transfer or discharge Type 1 Departments - Major A&E  \
# A&E attendances Type 1 Departments - Major A&E                                               0.837590
# A&E attendances Type 2 Departments - Single Spe...                                           0.511314
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.576296
# A&E attendances Total attendances                                                            0.833009
# A&E attendances less than 4 hours from arrival ...                                           0.626677
# A&E attendances less than 4 hours from arrival ...                                           0.503297
# A&E attendances less than 4 hours from arrival ...                                          -0.576376
# A&E attendances less than 4 hours from arrival ...                                           0.534440
# A&E attendances greater than 4 hours from arriv...                                           1.000000
# A&E attendances greater than 4 hours from arriv...                                           0.624208
# A&E attendances greater than 4 hours from arriv...                                          -0.368042
# A&E attendances greater than 4 hours from arriv...                                           0.999862
# Emergency Admissions Emergency Admissions via T...                                           0.771288
# Emergency Admissions Emergency Admissions via T...                                           0.364269
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.771246
# Emergency Admissions Other Emergency admissions...                                           0.455901
# Emergency Admissions Total Emergency Admissions                                              0.720963
# Emergency Admissions Number of patients spendin...                                           0.954705
# Emergency Admissions Number of patients spendin...                                           0.789706
#
#                                                     A&E attendances greater than 4 hours from arrival to admission, transfer or discharge Type 2 Departments - Single Specialty  \
# A&E attendances Type 1 Departments - Major A&E                                               0.632007
# A&E attendances Type 2 Departments - Single Spe...                                           0.784035
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.311971
# A&E attendances Total attendances                                                            0.797545
# A&E attendances less than 4 hours from arrival ...                                           0.546914
# A&E attendances less than 4 hours from arrival ...                                           0.770228
# A&E attendances less than 4 hours from arrival ...                                          -0.312014
# A&E attendances less than 4 hours from arrival ...                                           0.752088
# A&E attendances greater than 4 hours from arriv...                                           0.624208
# A&E attendances greater than 4 hours from arriv...                                           1.000000
# A&E attendances greater than 4 hours from arriv...                                          -0.199235
# A&E attendances greater than 4 hours from arriv...                                           0.635520
# Emergency Admissions Emergency Admissions via T...                                           0.524280
# Emergency Admissions Emergency Admissions via T...                                           0.656409
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.525874
# Emergency Admissions Other Emergency admissions...                                           0.014332
# Emergency Admissions Total Emergency Admissions                                              0.392881
# Emergency Admissions Number of patients spendin...                                           0.545602
# Emergency Admissions Number of patients spendin...                                           0.494965
#
#                                                     A&E attendances greater than 4 hours from arrival to admission, transfer or discharge Type 3 Departments - Other A&E/Minor Injury Unit  \
# A&E attendances Type 1 Departments - Major A&E                                              -0.553663
# A&E attendances Type 2 Departments - Single Spe...                                          -0.266055
# A&E attendances Type 3 Departments - Other A&E/...                                           0.658657
# A&E attendances Total attendances                                                           -0.381979
# A&E attendances less than 4 hours from arrival ...                                          -0.580691
# A&E attendances less than 4 hours from arrival ...                                          -0.266322
# A&E attendances less than 4 hours from arrival ...                                           0.654242
# A&E attendances less than 4 hours from arrival ...                                          -0.318661
# A&E attendances greater than 4 hours from arriv...                                          -0.368042
# A&E attendances greater than 4 hours from arriv...                                          -0.199235
# A&E attendances greater than 4 hours from arriv...                                           1.000000
# A&E attendances greater than 4 hours from arriv...                                          -0.359987
# Emergency Admissions Emergency Admissions via T...                                          -0.584295
# Emergency Admissions Emergency Admissions via T...                                          -0.244883
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                          -0.584140
# Emergency Admissions Other Emergency admissions...                                          -0.506768
# Emergency Admissions Total Emergency Admissions                                             -0.599806
# Emergency Admissions Number of patients spendin...                                          -0.354140
# Emergency Admissions Number of patients spendin...                                          -0.150670
#
#                                                     A&E attendances greater than 4 hours from arrival to admission, transfer or discharge Total Attendances > 4 hours  \
# A&E attendances Type 1 Departments - Major A&E                                               0.837352
# A&E attendances Type 2 Departments - Single Spe...                                           0.519054
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.571498
# A&E attendances Total attendances                                                            0.837309
# A&E attendances less than 4 hours from arrival ...                                           0.626417
# A&E attendances less than 4 hours from arrival ...                                           0.510850
# A&E attendances less than 4 hours from arrival ...                                          -0.571616
# A&E attendances less than 4 hours from arrival ...                                           0.540951
# A&E attendances greater than 4 hours from arriv...                                           0.999862
# A&E attendances greater than 4 hours from arriv...                                           0.635520
# A&E attendances greater than 4 hours from arriv...                                          -0.359987
# A&E attendances greater than 4 hours from arriv...                                           1.000000
# Emergency Admissions Emergency Admissions via T...                                           0.769374
# Emergency Admissions Emergency Admissions via T...                                           0.371092
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.769364
# Emergency Admissions Other Emergency admissions...                                           0.447987
# Emergency Admissions Total Emergency Admissions                                              0.716939
# Emergency Admissions Number of patients spendin...                                           0.953630
# Emergency Admissions Number of patients spendin...                                           0.790839
#
#                                                     Emergency Admissions Emergency Admissions via Type 1 A&E  \
# A&E attendances Type 1 Departments - Major A&E                                               0.968622
# A&E attendances Type 2 Departments - Single Spe...                                           0.582104
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.914913
# A&E attendances Total attendances                                                            0.826640
# A&E attendances less than 4 hours from arrival ...                                           0.943526
# A&E attendances less than 4 hours from arrival ...                                           0.579564
# A&E attendances less than 4 hours from arrival ...                                          -0.915040
# A&E attendances less than 4 hours from arrival ...                                           0.696841
# A&E attendances greater than 4 hours from arriv...                                           0.771288
# A&E attendances greater than 4 hours from arriv...                                           0.524280
# A&E attendances greater than 4 hours from arriv...                                          -0.584295
# A&E attendances greater than 4 hours from arriv...                                           0.769374
# Emergency Admissions Emergency Admissions via T...                                           1.000000
# Emergency Admissions Emergency Admissions via T...                                           0.484330
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.999994
# Emergency Admissions Other Emergency admissions...                                           0.702901
# Emergency Admissions Total Emergency Admissions                                              0.972007
# Emergency Admissions Number of patients spendin...                                           0.721321
# Emergency Admissions Number of patients spendin...                                           0.402386
#
#                                                     Emergency Admissions Emergency Admissions via Type 2 A&E  \
# A&E attendances Type 1 Departments - Major A&E                                               0.574138
# A&E attendances Type 2 Departments - Single Spe...                                           0.911511
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.383448
# A&E attendances Total attendances                                                            0.721762
# A&E attendances less than 4 hours from arrival ...                                           0.612042
# A&E attendances less than 4 hours from arrival ...                                           0.913351
# A&E attendances less than 4 hours from arrival ...                                          -0.383501
# A&E attendances less than 4 hours from arrival ...                                           0.833066
# A&E attendances greater than 4 hours from arriv...                                           0.364269
# A&E attendances greater than 4 hours from arriv...                                           0.656409
# A&E attendances greater than 4 hours from arriv...                                          -0.244883
# A&E attendances greater than 4 hours from arriv...                                           0.371092
# Emergency Admissions Emergency Admissions via T...                                           0.484330
# Emergency Admissions Emergency Admissions via T...                                           1.000000
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.487363
# Emergency Admissions Other Emergency admissions...                                          -0.103911
# Emergency Admissions Total Emergency Admissions                                              0.325098
# Emergency Admissions Number of patients spendin...                                           0.306375
# Emergency Admissions Number of patients spendin...                                           0.221631
#
#                                                     Emergency Admissions Emergency Admissions via Type 3 and 4 A&E  \
# A&E attendances Type 1 Departments - Major A&E                                                    NaN
# A&E attendances Type 2 Departments - Single Spe...                                                NaN
# A&E attendances Type 3 Departments - Other A&E/...                                                NaN
# A&E attendances Total attendances                                                                 NaN
# A&E attendances less than 4 hours from arrival ...                                                NaN
# A&E attendances less than 4 hours from arrival ...                                                NaN
# A&E attendances less than 4 hours from arrival ...                                                NaN
# A&E attendances less than 4 hours from arrival ...                                                NaN
# A&E attendances greater than 4 hours from arriv...                                                NaN
# A&E attendances greater than 4 hours from arriv...                                                NaN
# A&E attendances greater than 4 hours from arriv...                                                NaN
# A&E attendances greater than 4 hours from arriv...                                                NaN
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                                NaN
# Emergency Admissions Other Emergency admissions...                                                NaN
# Emergency Admissions Total Emergency Admissions                                                   NaN
# Emergency Admissions Number of patients spendin...                                                NaN
# Emergency Admissions Number of patients spendin...                                                NaN
#
#                                                     Emergency Admissions Total Emergency Admissions via A&E  \
# A&E attendances Type 1 Departments - Major A&E                                               0.969032
# A&E attendances Type 2 Departments - Single Spe...                                           0.584597
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.914671
# A&E attendances Total attendances                                                            0.827910
# A&E attendances less than 4 hours from arrival ...                                           0.944135
# A&E attendances less than 4 hours from arrival ...                                           0.582070
# A&E attendances less than 4 hours from arrival ...                                          -0.914798
# A&E attendances less than 4 hours from arrival ...                                           0.698802
# A&E attendances greater than 4 hours from arriv...                                           0.771246
# A&E attendances greater than 4 hours from arriv...                                           0.525874
# A&E attendances greater than 4 hours from arriv...                                          -0.584140
# A&E attendances greater than 4 hours from arriv...                                           0.769364
# Emergency Admissions Emergency Admissions via T...                                           0.999994
# Emergency Admissions Emergency Admissions via T...                                           0.487363
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           1.000000
# Emergency Admissions Other Emergency admissions...                                           0.701134
# Emergency Admissions Total Emergency Admissions                                              0.971423
# Emergency Admissions Number of patients spendin...                                           0.721147
# Emergency Admissions Number of patients spendin...                                           0.402490
#
#                                                     Emergency Admissions Other Emergency admissions (i.e not via A&E)  \
# A&E attendances Type 1 Departments - Major A&E                                               0.592397
# A&E attendances Type 2 Departments - Single Spe...                                          -0.088404
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.793519
# A&E attendances Total attendances                                                            0.264615
# A&E attendances less than 4 hours from arrival ...                                           0.586030
# A&E attendances less than 4 hours from arrival ...                                          -0.091339
# A&E attendances less than 4 hours from arrival ...                                          -0.793629
# A&E attendances less than 4 hours from arrival ...                                           0.072371
# A&E attendances greater than 4 hours from arriv...                                           0.455901
# A&E attendances greater than 4 hours from arriv...                                           0.014332
# A&E attendances greater than 4 hours from arriv...                                          -0.506768
# A&E attendances greater than 4 hours from arriv...                                           0.447987
# Emergency Admissions Emergency Admissions via T...                                           0.702901
# Emergency Admissions Emergency Admissions via T...                                          -0.103911
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.701134
# Emergency Admissions Other Emergency admissions...                                           1.000000
# Emergency Admissions Total Emergency Admissions                                              0.850339
# Emergency Admissions Number of patients spendin...                                           0.428442
# Emergency Admissions Number of patients spendin...                                           0.168630
#
#                                                     Emergency Admissions Total Emergency Admissions  \
# A&E attendances Type 1 Departments - Major A&E                                             0.912372
# A&E attendances Type 2 Departments - Single Spe...                                         0.402022
# A&E attendances Type 3 Departments - Other A&E/...                                        -0.939201
# A&E attendances Total attendances                                                          0.699106
# A&E attendances less than 4 hours from arrival ...                                         0.891877
# A&E attendances less than 4 hours from arrival ...                                         0.399179
# A&E attendances less than 4 hours from arrival ...                                        -0.939331
# A&E attendances less than 4 hours from arrival ...                                         0.539827
# A&E attendances greater than 4 hours from arriv...                                         0.720963
# A&E attendances greater than 4 hours from arriv...                                         0.392881
# A&E attendances greater than 4 hours from arriv...                                        -0.599806
# A&E attendances greater than 4 hours from arriv...                                         0.716939
# Emergency Admissions Emergency Admissions via T...                                         0.972007
# Emergency Admissions Emergency Admissions via T...                                         0.325098
# Emergency Admissions Emergency Admissions via T...                                              NaN
# Emergency Admissions Total Emergency Admissions...                                         0.971423
# Emergency Admissions Other Emergency admissions...                                         0.850339
# Emergency Admissions Total Emergency Admissions                                            1.000000
# Emergency Admissions Number of patients spendin...                                         0.674847
# Emergency Admissions Number of patients spendin...                                         0.353183
#
#                                                     Emergency Admissions Number of patients spending >4 hours from decision to admit to admission  \
# A&E attendances Type 1 Departments - Major A&E                                               0.782585
# A&E attendances Type 2 Departments - Single Spe...                                           0.450109
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.554527
# A&E attendances Total attendances                                                            0.762499
# A&E attendances less than 4 hours from arrival ...                                           0.573948
# A&E attendances less than 4 hours from arrival ...                                           0.443190
# A&E attendances less than 4 hours from arrival ...                                          -0.554604
# A&E attendances less than 4 hours from arrival ...                                           0.460511
# A&E attendances greater than 4 hours from arriv...                                           0.954705
# A&E attendances greater than 4 hours from arriv...                                           0.545602
# A&E attendances greater than 4 hours from arriv...                                          -0.354140
# A&E attendances greater than 4 hours from arriv...                                           0.953630
# Emergency Admissions Emergency Admissions via T...                                           0.721321
# Emergency Admissions Emergency Admissions via T...                                           0.306375
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.721147
# Emergency Admissions Other Emergency admissions...                                           0.428442
# Emergency Admissions Total Emergency Admissions                                              0.674847
# Emergency Admissions Number of patients spendin...                                           1.000000
# Emergency Admissions Number of patients spendin...                                           0.820008
#
#                                                     Emergency Admissions Number of patients spending >12 hours from decision to admit to admission
# A&E attendances Type 1 Departments - Major A&E                                               0.506022
# A&E attendances Type 2 Departments - Single Spe...                                           0.335394
# A&E attendances Type 3 Departments - Other A&E/...                                          -0.235925
# A&E attendances Total attendances                                                            0.570752
# A&E attendances less than 4 hours from arrival ...                                           0.273178
# A&E attendances less than 4 hours from arrival ...                                           0.327112
# A&E attendances less than 4 hours from arrival ...                                          -0.235958
# A&E attendances less than 4 hours from arrival ...                                           0.287163
# A&E attendances greater than 4 hours from arriv...                                           0.789706
# A&E attendances greater than 4 hours from arriv...                                           0.494965
# A&E attendances greater than 4 hours from arriv...                                          -0.150670
# A&E attendances greater than 4 hours from arriv...                                           0.790839
# Emergency Admissions Emergency Admissions via T...                                           0.402386
# Emergency Admissions Emergency Admissions via T...                                           0.221631
# Emergency Admissions Emergency Admissions via T...                                                NaN
# Emergency Admissions Total Emergency Admissions...                                           0.402490
# Emergency Admissions Other Emergency admissions...                                           0.168630
# Emergency Admissions Total Emergency Admissions                                              0.353183
# Emergency Admissions Number of patients spendin...                                           0.820008
# Emergency Admissions Number of patients spendin...                                           1.000000
